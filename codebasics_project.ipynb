# %% [markdown]
# ### NAME: AMBREEN ABDULRAHEEM
# ### SUBJECT: EXPLORATORY DATA ANALYSIS AND DATA VISUALIZAATION
# ### DATA NAME: LOK SABHA ELECTIONS
# ### CONTACT: ambreen.a.raheem@outlook.com
# ### GitHub: https://github.com/ambreenraheem

# %% [markdown]
# #### **ABOUT DATA**
# **AtliQ Media** is a private media company and they wanted to telecast a show on **Lok Sabha Elections 2024** in **India**.\
# They wanted to present insights from **2014** and **2019** elections without any biasand discuss less explored themes like voter turnout percentage in **India**.\
# The dataset is taken from the **ELECTION COMMITION OF INDIA.**\
# And provided by **CODEBASICS.**

# %% [markdown]
# ### First we need to import some very important libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Ambreen Abdulraheem\AppData\Local\Temp\ipykernel_17140\555797462.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # DATA TRANSFORMATION

# %% [markdown]
# ### 1. Establishing suitable dimention tables and primary keys to like the csv files effictively.
# ### 2. Constructing aggregstion tables using append and groupby functions as needed to formate the data appropriately for answering the querries.

# %% [markdown]
# ### Let's upload our .csv files of databases in python with the help of pandas.
# ### first df is (contituency_wise_results_2014) and
# ### second df2 is (constituency_wise_result_2019)

# %%
df = pd.read_csv("constituency_wise_results_2014.csv")
df
# Out:
#                state     pc_name             candidate  sex   age category  \
# 0     Andhra Pradesh   Adilabad           GODAM NAGESH    M  49.0       ST
# 1     Andhra Pradesh   Adilabad                 NARESH    M  37.0       ST
# 2     Andhra Pradesh   Adilabad          RAMESH RATHOD    M  48.0       ST
# 3     Andhra Pradesh   Adilabad        RATHOD SADASHIV    M  55.0       ST
# 4     Andhra Pradesh   Adilabad       NETHAWATH RAMDAS    M  44.0       ST
# ...              ...         ...                   ...  ...   ...      ...
# 8350      Puducherry  Puducherry  PUVALA NAGESWARA RAO    M  60.0      GEN
# 8351      Puducherry  Puducherry            K. MANJINI    M  41.0      GEN
# 8352      Puducherry  Puducherry            R. VALAVAN    M  40.0      GEN
# 8353      Puducherry  Puducherry             V. VIJAYA    F  29.0      GEN
# 8354      Puducherry  Puducherry     None of the Above  NaN   NaN      NaN
#
# ...

# %%
df2=pd.read_csv("constituency_wise_results_2019.csv")
df2
# Out:
#                state     pc_name  \
# 0     Andhra Pradesh      Aruku
# 1     Andhra Pradesh      Aruku
# 2     Andhra Pradesh      Aruku
# 3     Andhra Pradesh      Aruku
# 4     Andhra Pradesh      Aruku
# ...              ...         ...
# 8592      Puducherry  Puducherry
# 8593      Puducherry  Puducherry
# 8594      Puducherry  Puducherry
# 8595      Puducherry  Puducherry
# 8596      Puducherry  Puducherry
#
#                                               candidate     sex   age  \
# 0                                   KISHORE CHANDRA DEO    MALE  72.0
# 1     Dr. KOSURI KASI VISWANADHA VEERA VENKATA SATYA...    MALE  54.0
# 2                                      GODDETI. MADHAVI  FEMALE  26.0
# 3                                SHRUTI DEVI VYRICHERLA  FEMALE  46.0
# 4                                   GANGULAIAH VAMPURU.    MALE  49.0
# ...                                                 ...     ...   ...
# 8592                         TIRAVITAMANKAI@LOURDHUMARY  FEMALE  57.0
# ...

# %% [markdown]
# #### We need to save both files in MS.Excell.

# %%
df.to_excel("constituency_wise_results_2014.xlsx")

# %%
df2.to_excel("constituency_wise_results_2019.xlsx")

# %% [markdown]
# #### Let's do some initial analysis with pandas.
# #### Then we will continue or **Task.**

# %% [markdown]
# Columns names of dataset.

# %%
df.columns
# Out:
# Index(['state', 'pc_name', 'candidate', 'sex', 'age', 'category', 'party',
#        'party_symbol', 'general_votes', 'postal_votes', 'total_votes',
#        'total_electors'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['state', 'pc_name', 'candidate', 'sex', 'age', 'category', 'party',
#        'party_symbol', 'general_votes', 'postal_votes', 'total_votes',
#        'total_electors'],
#       dtype='object')

# %% [markdown]
# All the basic information of the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8355 entries, 0 to 8354
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   state           8355 non-null   object
#  1   pc_name         8355 non-null   object
#  2   candidate       8355 non-null   object
#  3   sex             7845 non-null   object
#  4   age             7845 non-null   float64
#  5   category        7845 non-null   object
#  6   party           8355 non-null   object
#  7   party_symbol    8355 non-null   object
#  8   general_votes   8355 non-null   int64
#  9   postal_votes    8355 non-null   int64
#  10  total_votes     8355 non-null   int64
#  11  total_electors  8355 non-null   int64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 783.4+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8597 entries, 0 to 8596
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   state           8597 non-null   object
#  1   pc_name         8597 non-null   object
#  2   candidate       8597 non-null   object
#  3   sex             8054 non-null   object
#  4   age             8054 non-null   float64
#  5   category        8054 non-null   object
#  6   party           8597 non-null   object
#  7   party_symbol    8054 non-null   object
#  8   general_votes   8597 non-null   int64
#  9   postal_votes    8597 non-null   int64
#  10  total_votes     8597 non-null   int64
#  11  total_electors  8597 non-null   int64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 806.1+ KB

# %% [markdown]
# #### After taking info of both datasets we will use .describe() function.
# (We can see big difference here also in both datasets.)

# %%
df.describe()
# Out:
#                age  general_votes  postal_votes    total_votes  total_electors
# count  7845.000000    8355.000000   8355.000000    8355.000000    8.355000e+03
# mean     47.135883   62132.985398    107.407660   62240.393058    1.574132e+06
# std      11.902487  140261.650370    436.090305  140535.827087    2.711797e+05
# min      25.000000     105.000000      0.000000     105.000000    4.992200e+04
# 25%      38.000000    1708.000000      0.000000    1708.500000    1.446478e+06
# 50%      46.000000    4350.000000      1.000000    4354.000000    1.578125e+06
# 75%      56.000000   14881.000000     13.000000   14886.000000    1.718414e+06
# max      93.000000  859973.000000   6792.000000  863358.000000    3.183083e+06

# %%
df2.describe()
# Out:
#                age  general_votes  postal_votes   total_votes  total_electors
# count  8054.000000   8.597000e+03   8597.000000  8.597000e+03    8.597000e+03
# mean     47.065185   7.117290e+04    267.469699  7.144037e+04    1.705181e+06
# std      12.140434   1.735669e+05    929.319680  1.742342e+05    2.969405e+05
# min      24.000000   8.400000e+01      0.000000  8.400000e+01    5.518900e+04
# 25%      38.000000   1.315000e+03      1.000000  1.317000e+03    1.553385e+06
# 50%      46.000000   3.341000e+03      4.000000  3.350000e+03    1.703279e+06
# 75%      56.000000   1.239100e+04     36.000000  1.242100e+04    1.856791e+06
# max      90.000000   1.066824e+06  19367.000000  1.068569e+06    3.150313e+06

# %% [markdown]
# Let's check it out if there are null values in both datasets.\
# (We have large numbers of null values in both datasets but there is no need of droping these columns,because we need NOTA values form it.)

# %%
df.isnull().sum()
# Out:
# state               0
# pc_name             0
# candidate           0
# sex               510
# age               510
# category          510
# party               0
# party_symbol        0
# general_votes       0
# postal_votes        0
# total_votes         0
# total_electors      0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# state               0
# pc_name             0
# candidate           0
# sex               543
# age               543
# category          543
# party               0
# party_symbol      543
# general_votes       0
# postal_votes        0
# total_votes         0
# total_electors      0
# dtype: int64

# %% [markdown]
# Unique numbers of values from the all columns of both datasets.\
# (As you can see there is huge difference between the number of states, pc_name, candidate, party, party_symbol, general_votes, postal_votes, total_votes, total_electors of the Election dataset.)

# %%
df.nunique()
# Out:
# state               33
# pc_name            508
# candidate         7563
# sex                  3
# age                 62
# category             4
# party              453
# party_symbol       131
# general_votes     6434
# postal_votes       796
# total_votes       6476
# total_electors     510
# dtype: int64

# %%
df2.nunique()
# Out:
# state               36
# pc_name            540
# candidate         7894
# sex                  3
# age                 63
# category             3
# party              674
# party_symbol       250
# general_votes     6233
# postal_votes      1227
# total_votes       6246
# total_electors     543
# dtype: int64

# %% [markdown]
# ### For insight of the null values is not difficult.
# (With sort_values function we can find the null values row by row or column by column of both datasets.)
# #### 10. Which constituency have voted the most for NOTA?

# %%
df.sort_values(by="sex",ascending=False)
# Out:
#               state                         pc_name             candidate  \
# 2490      Karnataka                     Chitradurga             T.BHAVANA
# 6987  Uttar Pradesh                          Deoria         BARKHA KINNAR
# 5684     Tamil Nadu                         Madurai     BHARATHI KANNAMMA
# 3578    Maharashtra                         Nagpur   SENAPATI UTTAM SAPAN
# 6514  Uttar Pradesh                          Amethi          SONAM KINNAR
# ...             ...                             ...                   ...
# 8278   NCT OF Delhi  NORTH WEST DELHI                   None of the Above
# 8296   NCT OF Delhi  WEST DELHI                         None of the Above
# 8316   NCT OF Delhi  SOUTH DELHI                        None of the Above
# 8323    Lakshadweep                     Lakshadweep     None of the Above
# 8354     Puducherry                      Puducherry     None of the Above
#
#       sex   age category party    party_symbol  general_votes  postal_votes  \
# ...

# %%
df.sort_values(by="age",ascending=False)
# Out:
#              state                         pc_name  \
# 1154         Bihar                    Hajipur (SC)
# 1559       Gujarat                     Gandhinagar
# 2953        Kerala              Thiruvananthapuram
# 1635       Gujarat                          Rajkot
# 801          Assam                          Jorhat
# ...            ...                             ...
# 8278  NCT OF Delhi  NORTH WEST DELHI
# 8296  NCT OF Delhi  WEST DELHI
# 8316  NCT OF Delhi  SOUTH DELHI
# 8323   Lakshadweep                     Lakshadweep
# 8354    Puducherry                      Puducherry
#
#                           candidate  sex   age category  party party_symbol  \
# 1154                 RAM SUNDAR DAS    M  93.0       SC  JD(U)        Arrow
# 1559                     L.K.ADVANI    M  86.0      GEN    BJP        Lotus
# 2953                    O RAJAGOPAL    M  84.0      GEN    BJP        Lotus
# 1635  PRAVINCHANDRA CHUNILAL PAREKH    M  83.0      GEN    IND          Hat
# ...

# %%
df.sort_values(by="category",ascending=False)
# Out:
#                state                         pc_name                candidate  \
# 0     Andhra Pradesh                       Adilabad              GODAM NAGESH
# 3814     Maharashtra                        Palghar   PANDURANG JETHYA PARDHI
# 7780       Jharkhand                        Rajmahal      VIJAY KUMAR HANSDAK
# 7779       Jharkhand                        Rajmahal             JYOTIN SOREN
# 7778       Jharkhand                        Rajmahal       ARJUN PRASAD SINGH
# ...              ...                             ...                      ...
# 8278    NCT OF Delhi  NORTH WEST DELHI                      None of the Above
# 8296    NCT OF Delhi  WEST DELHI                            None of the Above
# 8316    NCT OF Delhi  SOUTH DELHI                           None of the Above
# 8323     Lakshadweep                     Lakshadweep        None of the Above
# 8354      Puducherry                      Puducherry        None of the Above
#
# ...

# %%
df2.sort_values(by="sex",ascending=False)
# Out:
#               state                         pc_name  \
# 6181  Uttar Pradesh                           Kheri
# 6494  Uttar Pradesh                       Allahabad
# 6661  Uttar Pradesh                     Kushi Nagar
# 1305        Gujarat                  Ahmedabad East
# 2611         Kerala                       Ernakulam
# ...             ...                             ...
# 8518   NCT OF Delhi  NORTH WEST DELHI
# 8542   NCT OF Delhi  WEST DELHI
# 8570   NCT OF Delhi  SOUTH DELHI
# 8577    Lakshadweep                     Lakshadweep
# 8596     Puducherry                      Puducherry
#
#                                       candidate    sex   age category party  \
# 6181                                Paro Kinner  THIRD  33.0  GENERAL   IND
# 6494                              Bhawani Singh  THIRD  46.0       SC  AAAP
# 6661                               GUDDI KINNAR  THIRD  37.0  GENERAL   IND
# 1305  Jayswal Nareshkumar Babulal (Raju Mataji)  THIRD  28.0  GENERAL   IND
# ...

# %%
df2.sort_values(by="age",ascending=False)
# Out:
#                state                         pc_name  \
# 5585      Tamil Nadu                         Madurai
# 3118  Madhya Pradesh                          RATLAM
# 2266       Karnataka                          Tumkur
# 5913   Uttar Pradesh                         Sambhal
# 2010       Karnataka                         Belgaum
# ...              ...                             ...
# 8518    NCT OF Delhi  NORTH WEST DELHI
# 8542    NCT OF Delhi  WEST DELHI
# 8570    NCT OF Delhi  SOUTH DELHI
# 8577     Lakshadweep                     Lakshadweep
# 8596      Puducherry                      Puducherry
#
#                      candidate   sex   age category  party  \
# 5585                  ALAGAR P  MALE  90.0       SC   DMSK
# 3118         SURAJSINGH KALIYA  MALE  86.0       ST  JD(U)
# 2266           H. D. DEVEGOWDA  MALE  86.0  GENERAL  JD(S)
# 5913  DR. SHAFIQUR REHMAN BARQ  MALE  86.0  GENERAL     SP
# 2010   LAXMANRAO SOMANNA MELGE  MALE  84.0  GENERAL    IND
# ...

# %%
df2.sort_values(by="category",ascending=False)
# Out:
#                state                         pc_name  \
# 0     Andhra Pradesh                          Aruku
# 1504         Gujarat                  Chhota Udaipur
# 7570       Jharkhand                        Rajmahal
# 7568    Chhattisgarh                          KANKER
# 7567    Chhattisgarh                          KANKER
# ...              ...                             ...
# 8518    NCT OF Delhi  NORTH WEST DELHI
# 8542    NCT OF Delhi  WEST DELHI
# 8570    NCT OF Delhi  SOUTH DELHI
# 8577     Lakshadweep                     Lakshadweep
# 8596      Puducherry                      Puducherry
#
#                         candidate     sex   age category party  \
# 0             KISHORE CHANDRA DEO    MALE  72.0       ST   TDP
# 1504  RATHVA GITABEN VAJESINGBHAI  FEMALE  47.0       ST   BJP
# 7570                  GOPIN SOREN    MALE  56.0       ST  CPIM
# 7568              HARISINGH SIDAR    MALE  73.0       ST   IND
# ...

# %% [markdown]
# ### Total values of category columns.

# %%
df.category.value_counts()
# Out:
# category
# GEN    5318
# SC     2011
# ST      515
# Gen       1
# Name: count, dtype: int64

# %%
df2.category.value_counts()
# Out:
# category
# GENERAL    5317
# SC         2110
# ST          627
# Name: count, dtype: int64

# %% [markdown]
# ### Total values of sex columns.
# (We can see the majority of candidates are male in both elections, but in 2019 had some good involvement of female candidates..)

# %%
df.sex.value_counts()
# Out:
# sex
# M    7209
# F     630
# O       6
# Name: count, dtype: int64

# %%
df2.sex.value_counts()
# Out:
# sex
# MALE      7322
# FEMALE     726
# THIRD        6
# Name: count, dtype: int64

# %% [markdown]
# ### We can see the maximum & minimum turnout of general_votes from Election 2014 & 2019.

# %%
df.general_votes.max()
# Out:
# 859973

# %%
df.general_votes.min()
# Out:
# 105

# %%
df2.general_votes.max()
# Out:
# 1066824

# %%
df2.general_votes.min()
# Out:
# 84

# %% [markdown]
# ### Now we need to groupby **states** of **India** from dataset of **Constituency_wise_results_2014.csv**, then we will be try to analyze states one by one very closely for detail work..

# %%
df1=df.groupby('state')
df1

# %%
for stae, state_df in df1:
    print('state')
    print(state_df)
# Out:
# state
#                           state                    pc_name  \
# 8109  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8110  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8111  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8112  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8113  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8114  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8115  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8116  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8117  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8118  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8119  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8120  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8121  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8122  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8123  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# ...

# %%
df1.get_group('Andaman & Nicobar Islands')
# Out:
#                           state                    pc_name  \
# 8109  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8110  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8111  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8112  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8113  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8114  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8115  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8116  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8117  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8118  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8119  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8120  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8121  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8122  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8123  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# ...

# %%
df1.get_group('Andhra Pradesh')
# Out:
#               state    pc_name          candidate  sex   age category  party  \
# 0    Andhra Pradesh  Adilabad        GODAM NAGESH    M  49.0       ST    TRS
# 1    Andhra Pradesh  Adilabad              NARESH    M  37.0       ST    INC
# 2    Andhra Pradesh  Adilabad       RAMESH RATHOD    M  48.0       ST    TDP
# 3    Andhra Pradesh  Adilabad     RATHOD SADASHIV    M  55.0       ST    BSP
# 4    Andhra Pradesh  Adilabad    NETHAWATH RAMDAS    M  44.0       ST    IND
# ..              ...        ...                ...  ...   ...      ...    ...
# 635  Andhra Pradesh  Chittoor           UDAYA C.S    F  34.0       SC   PPOI
# 636  Andhra Pradesh  Chittoor       P. PUSHPA RAJ    M  57.0       SC  JaSPa
# 637  Andhra Pradesh  Chittoor      G.SAMANYAKIRAN    F  35.0       SC  YSRCP
# 638  Andhra Pradesh  Chittoor          S. ANJAPPA    M  43.0       SC    IND
# 639  Andhra Pradesh  Chittoor   None of the Above  NaN   NaN      NaN   NOTA
#
# ...

# %%
df1.get_group('Arunachal Pradesh')
# Out:
#                  state         pc_name          candidate  sex   age category  \
# 640  Arunachal Pradesh  ARUNACHAL WEST        GICHO KABAK    M  49.0       ST
# 641  Arunachal Pradesh  ARUNACHAL WEST      GUMJUM HAIDER    M  36.0       ST
# 642  Arunachal Pradesh  ARUNACHAL WEST       JALLEY SONAM    M  33.0       ST
# 643  Arunachal Pradesh  ARUNACHAL WEST       KIREN RIJIJU    M  42.0       ST
# 644  Arunachal Pradesh  ARUNACHAL WEST       TAKAM SANJOY    M  47.0       ST
# 645  Arunachal Pradesh  ARUNACHAL WEST      HABUNG PAYENG    M  56.0       ST
# 646  Arunachal Pradesh  ARUNACHAL WEST          TABA TAKU    M  34.0       ST
# 647  Arunachal Pradesh  ARUNACHAL WEST         SUBU KECHI    M  40.0       ST
# 648  Arunachal Pradesh  ARUNACHAL WEST  None of the Above  NaN   NaN      NaN
# 649  Arunachal Pradesh  ARUNACHAL EAST       NINONG ERING    M  55.0       ST
# 650  Arunachal Pradesh  ARUNACHAL EAST          TAPIR GAO    M  49.0       ST
# ...

# %%
df1.get_group('Assam')
# Out:
#      state     pc_name                candidate  sex   age category  party  \
# 653  Assam  Karimganj               KRISHNA DAS    M  45.0       SC    BJP
# 654  Assam  Karimganj   RABINDRA NATH CHOUDHURY    M  74.0       SC    AGP
# 655  Assam  Karimganj         RADHESHYAM BISWAS    M  59.0       SC  AIUDF
# 656  Assam  Karimganj   LALIT MOHON SUKLABAIDYA    M  72.0       SC    INC
# 657  Assam  Karimganj           TARUN KUMAR DAS    M  61.0       SC   AAAP
# ..     ...         ...                      ...  ...   ...      ...    ...
# 824  Assam   Lakhimpur            KHAIRUL ISLAM    M  38.0      GEN    IND
# 825  Assam   Lakhimpur               DAVID HORO    M  36.0      GEN    IND
# 826  Assam   Lakhimpur        RANJIT SINGH GORH    M  45.0      GEN    IND
# 827  Assam   Lakhimpur        HRISHIKESH BARUAH    M  27.0      GEN    IND
# 828  Assam   Lakhimpur        None of the Above  NaN   NaN      NaN   NOTA
#
# ...

# %%
df1.get_group('Bihar')
# Out:
#       state        pc_name                  candidate  sex   age category  \
# 829   Bihar  Valmiki Nagar               PURNMASI RAM    M  57.0       SC
# 830   Bihar  Valmiki Nagar  BAIDYA NATH PRASAD MAHATO    M  57.0      GEN
# 831   Bihar  Valmiki Nagar     SHAILESH KUMAR DIWAKAR    M  34.0       SC
# 832   Bihar  Valmiki Nagar       SATISH CHANDRA DUBEY    M  39.0      GEN
# 833   Bihar  Valmiki Nagar                AMAR SAHANI    M  38.0      GEN
# ...     ...            ...                        ...  ...   ...      ...
# 1471  Bihar     Jamui (SC)           VISHUN CHOUDHARY    M  56.0       SC
# 1472  Bihar     Jamui (SC)                DILIP KUMAR    M  30.0       SC
# 1473  Bihar     Jamui (SC)         MANOJ KUMAR MANJHI    M  32.0       SC
# 1474  Bihar     Jamui (SC)             SUBHASH PASWAN    M  45.0       SC
# 1475  Bihar     Jamui (SC)          None of the Above  NaN   NaN      NaN
#
#       party party_symbol  general_votes  postal_votes  total_votes  \
# ...

# %%
df1.get_group('Chandigarh')
# Out:
#            state     pc_name                        candidate  sex   age  \
# 8125  Chandigarh  CHANDIGARH                     KIRRON KHER     F  61.0
# 8126  Chandigarh  CHANDIGARH      JANNAT JAHAN-UL-HAQ (NAINA)    F  32.0
# 8127  Chandigarh  CHANDIGARH               PAWAN KUMAR BANSAL    M  65.0
# 8128  Chandigarh  CHANDIGARH                   KAWALJIT SINGH    M  33.0
# 8129  Chandigarh  CHANDIGARH                  KHEM LAL BANSAL    M  68.0
# 8130  Chandigarh  CHANDIGARH  GULKIRAT KAUR PANAG (GUL PANAG)    F  35.0
# 8131  Chandigarh  CHANDIGARH                 DHARMENDER SINGH    M  35.0
# 8132  Chandigarh  CHANDIGARH                   SURENDER KUMAR    M  32.0
# 8133  Chandigarh  CHANDIGARH                SURINDER BHARDWAJ    M  65.0
# 8134  Chandigarh  CHANDIGARH                      AJAY SINGLA    M  38.0
# 8135  Chandigarh  CHANDIGARH                     AMARJIT KAUR    F  55.0
# 8136  Chandigarh  CHANDIGARH                     JASMER SINGH    M  54.0
# ...

# %% [markdown]
# ## From here we will start analysis with the help of MySQL.

# %% [markdown]
# #### What is MySQL?
# #### Structured Query Language (SQL) is a standard computer language for retional data base management and data manipulation.

# %% [markdown]
# # Questions from the available data (Primary) with VISUALIZATIONS
# #### 1. List Top 5/ Bottom 5 states of 2014 and 2019 in turms of voter turnout ratio by GENERAL, STATE AND NATIONAL LEVEL?
# #### 2. Top 5 candidates based on margin difference with runners in 2014 and 2019 by GENERAL, STATE AND NATIONAL LEVEL?
# #### 3. List top 5/ Bottom 5 constituencies of 2014 and 2019 in terms of voter turnout ratio by GENERAL, STATE AND NATIONAL LEVEL?
# #### 4. Which constituencies have elected the same party for two consecutive electionsrank them by % of voes to that winning party in 2019?
# #### 5. Which constituencies have voted for different parties in two elections (List top 10 based on difference 2019_2014) in winner        vote percentage in two elections?
# #### 6. % Split of votes of parties between 2014 vs 2019 at national level?
# #### 7. % Split of votes of parties between 2014 vs 2019 at state level?
# #### 8. List of top 5 constituencies for two major national parties where they have gained vote share in 2019 as compare to 2014?
# #### 9. List of top 5 constituencies for two major national parties where they have lost vote share in 2019 as compare to 2014?
# #### 10. Which constituency have voted the most for NOTA?
# #### 11. Which constituencies have elected candidates whose party has less than 10% vote share at state level in 2019?

# %% [markdown]
# # GENERAL LEVEL 2014

# %%
dfall=pd.read_csv(r"c:\Users\Ambreen Abdulraheem\Desktop\mysql work\Lok_sabha_election2014_all.csv")
dfall
# Out:
#               state                     candidate category  total_votes  \
# 0    Andhra Pradesh  CHENNAMANENI VIDYA SAGAR RAO      GEN       214828
# 1    Andhra Pradesh              PONNAM PRABHAKAR      GEN       300706
# 2    Andhra Pradesh                   BURLA. RAVI      GEN         4769
# 3    Andhra Pradesh        VINOD KUMAR BOINAPALLY      GEN       505358
# 4    Andhra Pradesh            L. PRABHAKAR REDDY      GEN         3943
# ..              ...                           ...      ...          ...
# 995             Goa               ADV. SUHAS NAIK      GEN         5640
# 996             Goa             DR.DATTARAM DESAI      GEN        15857
# 997             Goa                   RAJU DSOUZA      GEN         3216
# 998             Goa          DAYANAND G. NARVEKAR      GEN         4128
# 999             Goa                 MITTU MUJAVAR      GEN         1813
#
#       party      pc_name
# 0       BJP  Karimnagar
# 1       INC  Karimnagar
# 2       NCP  Karimnagar
# ...

# %%
top_five_2014=dfall.nlargest(5, 'total_votes', keep='all')
top_five_2014
# Out:
#               state                      candidate category  total_votes  \
# 440           Assam             BIJOYA CHAKRAVARTY      GEN       764985
# 374  Andhra Pradesh             Y.S. AVINASH REDDY      GEN       671983
# 34   Andhra Pradesh  KALVAKUNTLA CHANDRASEKHAR RAO      GEN       657492
# 304  Andhra Pradesh         SAMBASIVA RAO RAYAPATI      GEN       632464
# 229  Andhra Pradesh           MURALI MOHAN MAGANTI      GEN       630573
#
#      party       pc_name
# 440    BJP       Gauhati
# 374  YSRCP        Kadapa
# 34     TRS         Medak
# 304    TDP  Narasaraopet
# 229    TDP   Rajahmundry

# %%
top_five_2014.plot(kind='bar',
           x='party',
           y='total_votes')
# Out:
# <Axes: xlabel='party'>

# %%
top_five_2014.plot(kind='bar',
           x='state',
           y='total_votes')
# Out:
# <Axes: xlabel='state'>

# %%
top_five_2014.plot(kind='bar',
           x='pc_name',
           y='total_votes')
# Out:
# <Axes: xlabel='pc_name'>

# %%
top_five_2014.plot(kind='bar',
           x='candidate',
           y='total_votes')
# Out:
# <Axes: xlabel='candidate'>

# %%
top_five_2014.plot.pie(y='total_votes')
# Out:
# <Axes: ylabel='total_votes'>

# %%
bottom_five_2014=dfall.nsmallest(5, 'total_votes', keep='all')
bottom_five_2014
# Out:
#              state                       candidate category  total_votes  \
# 95  Andhra Pradesh            MICHAEL DANIEL OVELZ      GEN          291
# 96  Andhra Pradesh  MOHD ABUBAKAR PARWAIZ SIDDIQUI      GEN          322
# 97  Andhra Pradesh         MOHAMMED RIZWAN HUSSAIN      GEN          370
# 99  Andhra Pradesh              SYED MADANI QUADRI      GEN          376
# 68  Andhra Pradesh              POTTURI TULASI DAS      GEN          411
#
#    party      pc_name
# 95   IND  Secundrabad
# 96   IND  Secundrabad
# 97   IND  Secundrabad
# 99   IND  Secundrabad
# 68   IND   Malkajgiri

# %%
bottom_five_2014.plot(kind='bar',
           x='party',
           y='total_votes')
# Out:
# <Axes: xlabel='party'>

# %%
bottom_five_2014.plot(kind='bar',
           x='candidate',
           y='total_votes')
# Out:
# <Axes: xlabel='candidate'>

# %%
bottom_five_2014.plot(kind='bar',
           x='state',
           y='total_votes')
# Out:
# <Axes: xlabel='state'>

# %%
bottom_five_2014.plot(kind='bar',
           x='pc_name',
           y='total_votes')
# Out:
# <Axes: xlabel='pc_name'>

# %%
bottom_five_2014.plot.pie(y='total_votes')
# Out:
# <Axes: ylabel='total_votes'>

# %% [markdown]
# # SC LAVEL 2014

# %%
dfallSC=pd.read_csv(r"c:\Users\Ambreen Abdulraheem\Desktop\mysql work\Lok_sabha_election2014_allSC.csv")
dfallSC
# Out:
#               state                         candidate category  total_votes  \
# 0    Andhra Pradesh            DR.JANAPATI SARAT BABU       SC        63334
# 1    Andhra Pradesh               TAGARAM SHANKAR LAL       SC         9449
# 2    Andhra Pradesh                       BALKA SUMAN       SC       565496
# 3    Andhra Pradesh                     G. VIVEKANAND       SC       274338
# 4    Andhra Pradesh                   KALVALA SHANKAR       SC         9290
# ..              ...                               ...      ...          ...
# 995          Punjab  MANJIT KAUR W/O SUKHWINDER SINGH       SC         1044
# 996          Punjab                       LOVE KISHOR       SC         3265
# 997          Punjab                       VIJAY KUMAR       SC         1528
# 998          Punjab                             VIVEK       SC          741
# 999          Punjab             BHAGWAN SINGH CHAUHAN       SC        40497
#
#     party      pc_name
# 0     TDP  Peddapalle
# ...

# %%
top_five_2014SC=dfallSC.nlargest(5, 'total_votes', keep='all')
top_five_2014SC
# Out:
#               state                  candidate category  total_votes party  \
# 680  Madhya Pradesh             MANOHAR UNTWAL       SC       665646   BJP
# 40   Andhra Pradesh            KADIYAM SRIHARI       SC       661639   TRS
# 690  Madhya Pradesh   PROF. CHINTAMANI MALVIYA       SC       641101   BJP
# 320         Gujarat        DR. KIRIT P SOLANKI       SC       617104   BJP
# 903     Maharashtra  DR. SUNIL BALIRAM GAIKWAD       SC       616509   BJP
#
#             pc_name
# 680           DEWAS
# 40         Warangal
# 690          UJJAIN
# 320  Ahmedabad West
# 903          Latur

# %%
top_five_2014SC.plot(kind='bar',
           x='party',
           y='total_votes')
# Out:
# <Axes: xlabel='party'>

# %%
top_five_2014SC.plot(kind='bar',
           x='state',
           y='total_votes')
# Out:
# <Axes: xlabel='state'>

# %%
top_five_2014SC.plot(kind='bar',
           x='pc_name',
           y='total_votes')
# Out:
# <Axes: xlabel='pc_name'>

# %%
top_five_2014SC.plot(kind='bar',
           x='candidate',
           y='total_votes')
# Out:
# <Axes: xlabel='candidate'>

# %%
bottom_five_2014SC=dfallSC.nsmallest(5, 'total_votes', keep='all')
bottom_five_2014SC
# Out:
#            state                  candidate category  total_votes party  \
# 406      Haryana                    HANSRAJ       SC          245   IND
# 859  Maharashtra        VIJAY LAXMAN SARODE       SC          303   IND
# 891  Maharashtra  SUMITRABAI DASHRATH PAWAR       SC          314   IND
# 408      Haryana                     JAGBIR       SC          357   IND
# 860  Maharashtra   SHASHIKANT BHIKAJI OWHAL       SC          359   IND
#
#      pc_name
# 406    Hisar
# 859     Pune
# 891     Beed
# 408  Sonipat
# 860     Pune

# %%
bottom_five_2014SC.plot(kind='bar',
           x='candidate',
           y='total_votes')
# Out:
# <Axes: xlabel='candidate'>

# %%
bottom_five_2014SC.plot(kind='bar',
           x='state',
           y='total_votes')
# Out:
# <Axes: xlabel='state'>

# %%
bottom_five_2014SC.plot(kind='bar',
           x='pc_name',
           y='total_votes')
# Out:
# <Axes: xlabel='pc_name'>

# %%
bottom_five_2014SC.plot(kind='bar',
           x='party',
           y='total_votes')
# Out:
# <Axes: xlabel='party'>

# %% [markdown]
# # ST LEVEL 2014

# %%
dfallST=pd.read_csv(r"c:\Users\Ambreen Abdulraheem\Desktop\mysql work\Lok_sabha_election2014_allST.csv")
dfallST
# Out:
#               state                 candidate category  total_votes party  \
# 0    Andhra Pradesh              GODAM NAGESH       ST       430847   TRS
# 1    Andhra Pradesh                    NARESH       ST       259557   INC
# 2    Andhra Pradesh             RAMESH RATHOD       ST       184198   TDP
# 3    Andhra Pradesh           RATHOD SADASHIV       ST        94420   BSP
# 4    Andhra Pradesh          NETHAWATH RAMDAS       ST        41032   IND
# ..              ...                       ...      ...          ...   ...
# 510     Lakshadweep            NAJMUDHEEN C.T       ST          181   CPI
# 511     Lakshadweep      MOHAMMED FAIZAL P.P.       ST        21665   NCP
# 512     Lakshadweep  M.P. SAYED MOHAMMED KOYA       ST          187   BJP
# 513     Lakshadweep          HAMDULLAH SAYEED       ST        20130   INC
# 514     Lakshadweep              KOMALAM KOYA       ST          488    SP
#
#          pc_name
# 0      Adilabad
# 1      Adilabad
# 2      Adilabad
# ...

# %%
top_five_2014ST=dfallST.nlargest(5, 'total_votes', keep='all')
top_five_2014ST
# Out:
#               state        candidate category  total_votes party   pc_name
# 316        Nagaland      NEIPHIU RIO       ST       713372   NPF  Nagaland
# 400     West Bengal        UMA SAREN       ST       674504  AITC  Jhargram
# 341       Rajasthan  ARJUNLAL MEENA        ST       660373   BJP   Udaipur
# 226  Madhya Pradesh    SUBHASH PATEL       ST       649354   BJP  KHARGONE
# 233  Madhya Pradesh     JYOTI DHURVE       ST       643651   BJP     BETUL

# %%
top_five_2014ST.plot(kind='bar',
           x='party',
           y='total_votes')
# Out:
# <Axes: xlabel='party'>

# %%
top_five_2014ST.plot(kind='bar',
           x='candidate',
           y='total_votes')
# Out:
# <Axes: xlabel='candidate'>

# %%
top_five_2014ST.plot(kind='bar',
           x='state',
           y='total_votes')
# Out:
# <Axes: xlabel='state'>

# %%
top_five_2014ST.plot(kind='bar',
           x='pc_name',
           y='total_votes')
# Out:
# <Axes: xlabel='pc_name'>

# %%
bottom_five_2014ST=dfallST.nsmallest(5, 'total_votes', keep='all')
bottom_five_2014ST
# Out:
#                     state                  candidate category  total_votes  \
# 510           Lakshadweep             NAJMUDHEEN C.T       ST          181
# 512           Lakshadweep   M.P. SAYED MOHAMMED KOYA       ST          187
# 504  Dadra & Nagar Haveli  VIJAYBHAI NATHUBHAI BHOYA       ST          232
# 505  Dadra & Nagar Haveli   UMEDBHAI LALLUBHAI PATEL       ST          348
# 502  Dadra & Nagar Haveli       KISHAN NATHU GHUTIYA       ST          378
#
#      party               pc_name
# 510    CPI           Lakshadweep
# 512    BJP           Lakshadweep
# 504  JD(U)  Dadar & Nagar Haveli
# 505   BMUP  Dadar & Nagar Haveli
# 502    SHS  Dadar & Nagar Haveli

# %%
bottom_five_2014ST.plot(kind='bar',
           x='state',
           y='total_votes')
# Out:
# <Axes: xlabel='state'>

# %%
bottom_five_2014ST.plot(kind='bar',
           x='party',
           y='total_votes')
# Out:
# <Axes: xlabel='party'>

# %%
bottom_five_2014ST.plot(kind='bar',
           x='candidate',
           y='total_votes')
# Out:
# <Axes: xlabel='candidate'>

# %%
bottom_five_2014ST.plot(kind='bar',
           x='pc_name',
           y='total_votes')
# Out:
# <Axes: xlabel='pc_name'>

# %% [markdown]
# ### Now we need to groupby **states** of **India** from dataset of **Constituency_wise_results_2019.csv**, then we will be try to analyze states one by one very closely for detail work..

# %%
df3=df2.groupby('state')
df3

# %%
for stae, state_df in df3:
    print('state')
    print(state_df)
# Out:
# state
#                           state                    pc_name  \
# 8330  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8331  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8332  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8333  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8334  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8335  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8336  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8337  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8338  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8339  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8340  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8341  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8342  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8343  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8344  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# ...

# %% [markdown]
# # GENERAL LEVEL 2019

# %%
dfallGEN=pd.read_csv(r"c:\Users\Ambreen Abdulraheem\Desktop\mysql work\Lok_sabha_election2019_allGENERAL.csv")
dfallGEN
# Out:
#               state                        candidate category  total_votes  \
# 0    Andhra Pradesh        KINJARAPU RAM MOHAN NAIDU  GENERAL       534544
# 1    Andhra Pradesh                       DOLA JAGAN  GENERAL        13745
# 2    Andhra Pradesh                 DUVVADA SRINIVAS  GENERAL       527891
# 3    Andhra Pradesh               PERLA SAMBA MURTHY  GENERAL         8390
# 4    Andhra Pradesh        MATTA SATISH CHAKRAVARTHY  GENERAL         1448
# ..              ...                              ...      ...          ...
# 995         Gujarat         VALA JAYPALSINH HAJABHAI  GENERAL         4165
# 996         Gujarat         HARESH MANUBHAI SARDHARA  GENERAL         3491
# 997         Gujarat  Kachhadiya Naranbhai Bhikhabhai  GENERAL       529035
# 998         Gujarat                   Paresh Dhanani  GENERAL       327604
# 999         Gujarat    Dhapa Dharamshibhai Ramjibhai  GENERAL         4747
#
#      party     pc_name
# 0      TDP  Srikakulam
# ...

# %%
top_five_2019=dfallGEN.nlargest(5, 'total_votes', keep='all')
top_five_2019
# Out:
#               state                        candidate category  total_votes  \
# 266           Assam                        QUEEN OJA  GENERAL      1008936
# 892         Gujarat                        AMIT SHAH  GENERAL       894624
# 303           Assam                     Gaurav Gogoi  GENERAL       786092
# 193  Andhra Pradesh                Y.S.Avinash Reddy  GENERAL       783499
# 947         Gujarat  KUNDARIA MOHANBHAI KALYANJIBHAI  GENERAL       758645
#
#      party      pc_name
# 266    BJP      Gauhati
# 892    BJP  Gandhinagar
# 303    INC     Kaliabor
# 193  YSRCP       Kadapa
# 947    BJP       Rajkot

# %%
top_five_2019.plot(kind='bar',
           x='party',
           y='total_votes')
# Out:
# <Axes: xlabel='party'>

# %%
top_five_2019.plot(kind='bar',
           x='state',
           y='total_votes')
# Out:
# <Axes: xlabel='state'>

# %%
top_five_2019.plot(kind='bar',
           x='pc_name',
           y='total_votes')
# Out:
# <Axes: xlabel='pc_name'>

# %%
top_five_2019.plot(kind='bar',
           x='candidate',
           y='total_votes')
# Out:
# <Axes: xlabel='candidate'>

# %%
bottom_five_2019=dfallGEN.nsmallest(5, 'total_votes', keep='all')
bottom_five_2019
# Out:
#               state                         candidate category  total_votes  \
# 128  Andhra Pradesh                     KANTE SAYANNA  GENERAL          365
# 199  Andhra Pradesh               Putha Lakshmi Reddy  GENERAL          368
# 980         Gujarat  BHANDERI AMARSHIBHAI CHHAGANBHAI  GENERAL          396
# 103  Andhra Pradesh                         Sk. Riyaz  GENERAL          412
# 969         Gujarat                   AMANDBHAI PATEL  GENERAL          413
#
#     party       pc_name
# 128   IND  Narasaraopet
# 199  RDHP        Kadapa
# 980   IND      Jamnagar
# 103  IUML    Vijayawada
# 969   IND      Jamnagar

# %%
bottom_five_2019.plot(kind='bar',
           x='candidate',
           y='total_votes')
# Out:
# <Axes: xlabel='candidate'>

# %%
bottom_five_2019.plot(kind='bar',
           x='party',
           y='total_votes')
# Out:
# <Axes: xlabel='party'>

# %%
bottom_five_2019.plot(kind='bar',
           x='state',
           y='total_votes')
# Out:
# <Axes: xlabel='state'>

# %%
bottom_five_2019.plot(kind='bar',
           x='pc_name',
           y='total_votes')
# Out:
# <Axes: xlabel='pc_name'>

# %% [markdown]
# # SC LEVEL 2019

# %%
dfallSC19=pd.read_csv(r"c:\Users\Ambreen Abdulraheem\Desktop\mysql work\Lok_sabha_election2019_allSC.csv")
dfallSC19
# Out:
#               state                  candidate category  total_votes  \
# 0    Andhra Pradesh        Yella Rao Siyyadula       SC         1010
# 1    Andhra Pradesh             GEORGE BANGARI       SC         3028
# 2    Andhra Pradesh  Vadlamuri Krishna Swaroop       SC         4444
# 3    Andhra Pradesh    APPALAKONDA VANGALAPUDI       SC         2997
# 4    Andhra Pradesh       GODUGU SATYANARAYANA       SC         1724
# ..              ...                        ...      ...          ...
# 995          Punjab            PARWINDER SINGH       SC         1727
# 996          Punjab         PURAN SINGH SHEIKH       SC         2452
# 997          Punjab          ONKAR SINGH UPPAL       SC         1161
# 998          Punjab                HARJIT KAUR       SC         1341
# 999          Punjab                 JAGIR KAUR       SC         4311
#
#           party        pc_name
# 0           IND   Vizianagaram
# 1           VCK  Visakhapatnam
# 2         DABAP     Anakapalli
# ...

# %%
top_five_2019=dfallSC19.nlargest(5, 'total_votes', keep='all')
top_five_2019
# Out:
#               state               candidate category  total_votes  party  \
# 651  Madhya Pradesh  MAHENDRA SINGH SOLANKY       SC       862429    BJP
# 655  Madhya Pradesh           ANIL FIROJIYA       SC       791663    BJP
# 303         Haryana      RATTAN LAL KATARIA       SC       746508    BJP
# 62   Andhra Pradesh  Balli Durga Prasad Rao       SC       722877  YSRCP
# 326         Haryana           Sunita Duggal       SC       714351    BJP
#
#        pc_name
# 651      DEWAS
# 655     UJJAIN
# 303     Ambala
# 62   Tirupati
# 326      Sirsa

# %%
top_five_2019.plot(kind='bar',
           x='party',
           y='total_votes')
# Out:
# <Axes: xlabel='party'>

# %%
top_five_2019.plot(kind='bar',
           x='pc_name',
           y='total_votes')
# Out:
# <Axes: xlabel='pc_name'>

# %%
top_five_2019.plot(kind='bar',
           x='state',
           y='total_votes')
# Out:
# <Axes: xlabel='state'>

# %%
top_five_2019.plot(kind='bar',
           x='candidate',
           y='total_votes')
# Out:
# <Axes: xlabel='candidate'>

# %%
bottom_five_2019=dfallSC19.nsmallest(5, 'total_votes', keep='all')
bottom_five_2019
# Out:
#            state                      candidate category  total_votes party  \
# 826  Maharashtra  Sawant Chandrakant Parmeshwar       SC          161   IND
# 824  Maharashtra     Ravindra Bansiram Mahapure       SC          171   IND
# 735  Maharashtra           KARTIK GENDALAL DOKE       SC          181   IND
# 738  Maharashtra        SACHIN HARIDAS SOMKUWAR       SC          227   IND
# 825  Maharashtra          Vijay Laxaman Saroade       SC          230   IND
#
#      pc_name
# 826     Pune
# 824     Pune
# 735  Nagpur
# 738  Nagpur
# 825     Pune

# %%
bottom_five_2019.plot(kind='bar',
           x='candidate',
           y='total_votes')
# Out:
# <Axes: xlabel='candidate'>

# %%
bottom_five_2019.plot(kind='bar',
           x='party',
           y='total_votes')
# Out:
# <Axes: xlabel='party'>

# %%
bottom_five_2019.plot(kind='bar',
           x='state',
           y='total_votes')
# Out:
# <Axes: xlabel='state'>

# %%
bottom_five_2019.plot(kind='bar',
           x='pc_name',
           y='total_votes')
# Out:
# <Axes: xlabel='pc_name'>

# %% [markdown]
# # ST LEVEL 2019

# %%
dfallST19=pd.read_csv(r"c:\Users\Ambreen Abdulraheem\Desktop\mysql work\Lok_sabha_election2019_allST.csv")
dfallST19
# Out:
#               state                                          candidate  \
# 0    Andhra Pradesh                                KISHORE CHANDRA DEO
# 1    Andhra Pradesh  Dr. KOSURI KASI VISWANADHA VEERA VENKATA SATYA...
# 2    Andhra Pradesh                                   GODDETI. MADHAVI
# 3    Andhra Pradesh                             SHRUTI DEVI VYRICHERLA
# 4    Andhra Pradesh                                GANGULAIAH VAMPURU.
# ..              ...                                                ...
# 622     Lakshadweep                                       ALI AKBAR K.
# 623     Lakshadweep                                 MOHAMMED FAIZAL PP
# 624     Lakshadweep                                       SHAREEF KHAN
# 625     Lakshadweep                                   HAMDULLAH SAYEED
# 626     Lakshadweep                            DR. MOHAMMED SADIQUE KP
#
#     category  total_votes  party      pc_name
# 0         ST       338101    TDP       Aruku
# ...

# %%
top_five_2019=dfallST19.nlargest(5, 'total_votes', keep='all')
top_five_2019
# Out:
#               state                   candidate category  total_votes party  \
# 355       Rajasthan              ARJUNLAL MEENA       ST       871548   BJP
# 208  Madhya Pradesh      DURGA DAS (D.D.) UIKEY       ST       811248   BJP
# 40            Assam               PRADAN BARUAH       ST       776406   BJP
# 199  Madhya Pradesh  GAJENDRA UMRAO SINGH PATEL       ST       773550   BJP
# 88          Gujarat                Dr.K.C.PATEL       ST       771980   BJP
#
#        pc_name
# 355    Udaipur
# 208      BETUL
# 40   Lakhimpur
# 199   KHARGONE
# 88      Valsad

# %%
top_five_2019.plot(kind='bar',
           x='candidate',
           y='total_votes')
# Out:
# <Axes: xlabel='candidate'>

# %%
top_five_2019.plot(kind='bar',
           x='party',
           y='total_votes')
# Out:
# <Axes: xlabel='party'>

# %%
top_five_2019.plot(kind='bar',
           x='state',
           y='total_votes')
# Out:
# <Axes: xlabel='state'>

# %%
top_five_2019.plot(kind='bar',
           x='pc_name',
           y='total_votes')
# Out:
# <Axes: xlabel='pc_name'>

# %%
bottom_five_2019=dfallST19.nsmallest(5, 'total_votes', keep='all')
bottom_five_2019
# Out:
#            state                candidate category  total_votes    party  \
# 621  Lakshadweep        ABDUL KHADER HAJI       ST          125      BJP
# 622  Lakshadweep             ALI AKBAR K.       ST          143      CPI
# 231  Maharashtra    SATISH VITTHAL NIKHAR       ST          237      IND
# 131       Kerala  PRAVEEN ARIMBRATHODIYIL       ST          318      IND
# 580    Telangana              J . MALLESH       ST          334  SUCI(C)
#
#          pc_name
# 621  Lakshadweep
# 622  Lakshadweep
# 231      Nagpur
# 131       Kannur
# 580  Secundrabad

# %%
bottom_five_2019.plot(kind='bar',
           x='candidate',
           y='total_votes')
# Out:
# <Axes: xlabel='candidate'>

# %%
bottom_five_2019.plot(kind='bar',
           x='party',
           y='total_votes')
# Out:
# <Axes: xlabel='party'>

# %%
bottom_five_2019.plot(kind='bar',
           x='state',
           y='total_votes')
# Out:
# <Axes: xlabel='state'>

# %%
bottom_five_2019.plot(kind='bar',
           x='pc_name',
           y='total_votes')
# Out:
# <Axes: xlabel='pc_name'>

# %% [markdown]
# ## Top 5 and Bottom 5 votes turnout ratio by state,pc_name,party and category..

# %%
votes_ratio19=pd.read_csv(r"c:\Users\Ambreen Abdulraheem\Desktop\mysql work\Lok_sabha_election2019_ratio.csv")
votes_ratio19
# Out:
#               state                                          candidate  \
# 0    Andhra Pradesh                                KISHORE CHANDRA DEO
# 1    Andhra Pradesh  Dr. KOSURI KASI VISWANADHA VEERA VENKATA SATYA...
# 2    Andhra Pradesh                                   GODDETI. MADHAVI
# 3    Andhra Pradesh                             SHRUTI DEVI VYRICHERLA
# 4    Andhra Pradesh                                GANGULAIAH VAMPURU.
# ..              ...                                                ...
# 995           Bihar                   Uday Narayan Rai @ Luddu Rajbhar
# 996           Bihar                      Dhanjit Singh @ Dhanjit Kumar
# 997           Bihar                                           Ravi Raj
# 998           Bihar                                Binod Kumar Bikrant
# 999           Bihar                                Santosh Kumar Yadav
#
#     category  party pc_name  total_votes   ratio
# 0         ST    TDP  Aruku        338101  0.2329
# ...

# %%
top_five_ratio19=votes_ratio19.nlargest(5, 'ratio', keep='all')
top_five_ratio19
# Out:
#                  state                   candidate category  party  \
# 458              Assam               RAMESWAR TELI  GENERAL    BJP
# 262     Andhra Pradesh           Y.S.Avinash Reddy  GENERAL  YSRCP
# 319  Arunachal Pradesh                KIREN RIJIJU       ST    BJP
# 359              Assam              HOREN SING BEY       ST    BJP
# 191     Andhra Pradesh  MAGUNTA SREENIVASULU REDDY  GENERAL  YSRCP
#
#                  pc_name  total_votes   ratio
# 458            Dibrugarh       659583  0.5018
# 262               Kadapa       783499  0.4989
# 319       ARUNACHAL WEST       225796  0.4869
# 359  Autonomous District       381316  0.4791
# 191              Ongole        739202  0.4749

# %%
top_five_ratio19.plot(kind='bar',
           x='ratio',
           y='total_votes')
# Out:
# <Axes: xlabel='ratio'>

# %%
bottom_five_ratio19=votes_ratio19.nsmallest(10, 'ratio', keep='all')
bottom_five_ratio19
# Out:
#               state                               candidate category  party  \
# 139  Andhra Pradesh                               Sk. Riyaz  GENERAL   IUML
# 172  Andhra Pradesh                           KANTE SAYANNA  GENERAL    IND
# 268  Andhra Pradesh                     Putha Lakshmi Reddy  GENERAL   RDHP
# 135  Andhra Pradesh                        DATLA LURDU MARY       SC    MPP
# 136  Andhra Pradesh                      PADALA SIVA PRASAD  GENERAL   NRCP
# 150  Andhra Pradesh  Ullagi David Jayakumar (Dr. D J Kumar)  GENERAL   HMRD
# 151  Andhra Pradesh                        Jeldi Raja Mohan       SC  AINPP
# 158  Andhra Pradesh                            Shaik Jaleel  GENERAL   NRCP
# 171  Andhra Pradesh                     SURABHI DEVASAHAYAM       SC   IUML
# 184  Andhra Pradesh               CHINA NAGESWARA RAO SADHU       SC    MPP
# 185  Andhra Pradesh                            THUMATI RAVI       SC   AlPP
# ...

# %%
bottom_five_ratio19.plot(kind='bar',
           x='ratio',
           y='total_votes')
# Out:
# <Axes: xlabel='ratio'>

# %%
votes_ratio14=pd.read_csv(r"c:\Users\Ambreen Abdulraheem\Desktop\mysql work\Lok_sabha_election2014_ratio.csv")
votes_ratio14
# Out:
#               state               candidate category party      pc_name  \
# 0    Andhra Pradesh            GODAM NAGESH       ST   TRS    Adilabad
# 1    Andhra Pradesh                  NARESH       ST   INC    Adilabad
# 2    Andhra Pradesh           RAMESH RATHOD       ST   TDP    Adilabad
# 3    Andhra Pradesh         RATHOD SADASHIV       ST   BSP    Adilabad
# 4    Andhra Pradesh        NETHAWATH RAMDAS       ST   IND    Adilabad
# ..              ...                     ...      ...   ...          ...
# 995           Bihar       KAMLESH CHOUDHARY       SC   IND  Muzaffarpur
# 996           Bihar            DEEPAK KUMAR      GEN   IND  Muzaffarpur
# 997           Bihar  NAGESHWAR PRASAD SINGH      GEN   IND  Muzaffarpur
# 998           Bihar           MAHESH PASWAN       SC   IND  Muzaffarpur
# 999           Bihar  MOHAMMAD ANWARUL HAQUE      GEN   IND  Muzaffarpur
#
#      total_votes   ratio
# 0         430847  0.3108
# 1         259557  0.1872
# 2         184198  0.1329
# ...

# %%
top_five_ratio14=votes_ratio14.nlargest(5, 'ratio', keep='all')
top_five_ratio14
# Out:
#               state                        candidate category  party  \
# 363  Andhra Pradesh             MURALI MOHAN MAGANTI      GEN    TDP
# 754           Assam                    RAMESWAR TELI      GEN    BJP
# 349  Andhra Pradesh         DR PANDULA RAVINDRA BABU       SC    TDP
# 390  Andhra Pradesh  MAGANTI VENKATESWARA RAO (BABU)      GEN    TDP
# 543  Andhra Pradesh               Y.S. AVINASH REDDY      GEN  YSRCP
#
#          pc_name  total_votes   ratio
# 363  Rajahmundry       630573  0.4437
# 754    Dibrugarh       494364  0.4397
# 349  Amalapuram        594547  0.4379
# 390       Eluru        623471  0.4367
# 543       Kadapa       671983  0.4334

# %%
top_five_ratio14.plot(kind='bar',
           x='ratio',
           y='total_votes')
# Out:
# <Axes: xlabel='ratio'>

# %%
bottom_five_ratio14=votes_ratio14.nsmallest(5, 'ratio', keep='all')
bottom_five_ratio14
# Out:
#               state                          candidate category   party  \
# 104  Andhra Pradesh                 POTTURI TULASI DAS      GEN     IND
# 92   Andhra Pradesh  SATHYANARAYANA YAADAV PEDDIBOYINA      GEN   BCBDP
# 93   Andhra Pradesh                 SUTHARAPU PADMAIAH      GEN  APRSSP
# 105  Andhra Pradesh              POLISETTY KRISHNA RAO      GEN     IND
# 110  Andhra Pradesh           B.VEERA HANUMANTHA REDDY      GEN     IND
# 135  Andhra Pradesh               MICHAEL DANIEL OVELZ      GEN     IND
# 136  Andhra Pradesh     MOHD ABUBAKAR PARWAIZ SIDDIQUI      GEN     IND
# 137  Andhra Pradesh            MOHAMMED RIZWAN HUSSAIN      GEN     IND
# 139  Andhra Pradesh                 SYED MADANI QUADRI      GEN     IND
#
#          pc_name  total_votes   ratio
# 104   Malkajgiri          411  0.0001
# 92    Malkajgiri          596  0.0002
# 93    Malkajgiri          529  0.0002
# 105   Malkajgiri          496  0.0002
# 110   Malkajgiri          775  0.0002
# ...

# %%
bottom_five_ratio14.plot(kind='bar',
           x='ratio',
           y='total_votes')
# Out:
# <Axes: xlabel='ratio'>

# %% [markdown]
# # PROJECT END
